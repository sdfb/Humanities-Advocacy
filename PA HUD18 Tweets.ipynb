# %%
import pandas as pd

# %%
data = pd.read_csv('PA Congressional Delegation Social Media Handles.csv', header=None)

# %%
data
# Out:
#                       0                           1                 2  \
# 0        Patrick Toomey                Pennsylvania        @SenToomey
# 1        Bob Casey, Jr.                Pennsylvania      @SenBobCasey
# 2           Marino, Tom  Pennsylvania 10th District     @RepTomMarino
# 3         Barletta, Lou  Pennsylvania 11th District   @RepLouBarletta
# 4        Rothfus, Keith  Pennsylvania 12th District     @KeithRothfus
# 5        Boyle, Brendan  Pennsylvania 13th District  @RepBrendanBoyle
# 6           Doyle, Mike  Pennsylvania 14th District   @USRepMikeDoyle
# 7      Dent, Charles W.  Pennsylvania 15th District   @RepCharlieDent
# 8        Smucker, Lloyd  Pennsylvania 16th District   @SenatorSmucker
# 9   Cartwright, Matthew  Pennsylvania 17th District    @RepCartwright
# 10          Murphy, Tim  Pennsylvania 18th District     @RepTimMurphy
# 11        Brady, Robert   Pennsylvania 1st District         @RepBrady
# ...

# %%
text = "Thank you to Congressman {0} and  for meeting with PA advocates for the humanities.  Our vital work in history, literature, archives, museums, & languages would not be possible without your support.  The humanities are essential for the soul of the nation and for {1}. #HAD18 @humanitiesall\n"

# %%
for index, row in data.iterrows():
    twitter = row[2]
    district = row[1]
    
    print(text.format(twitter, district))
# Out:
# Thank you to Congressman @SenToomey and  for meeting with PA advocates for the humanities.  Our vital work in history, literature, archives, museums, & languages would not be possible without your support.  The humanities are essential for the soul of the nation and for Pennsylvania. #HAD18 @humanitiesall
#
# Thank you to Congressman @SenBobCasey and  for meeting with PA advocates for the humanities.  Our vital work in history, literature, archives, museums, & languages would not be possible without your support.  The humanities are essential for the soul of the nation and for Pennsylvania. #HAD18 @humanitiesall
#
# Thank you to Congressman @RepTomMarino and  for meeting with PA advocates for the humanities.  Our vital work in history, literature, archives, museums, & languages would not be possible without your support.  The humanities are essential for the soul of the nation and for Pennsylvania 10th District. #HAD18 @humanitiesall
#
# ...
